# %% [markdown]
# <a href="https://colab.research.google.com/github/AdityaGaur77/sudoku_solver/blob/main/tiffy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install rasterio matplotlib.colors

# %% [markdown]
# # **CO2**

# %%
# COLORIZING THE MAP: NIKHIL KONDURU

import rasterio
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

tiff = '/content/MiCASA_v1_ATMC_x3600_y1800_daily_20010101.tif'


with rasterio.open(tiff) as src:
    emissions_data = src.read(1)

colors = ['white','green','green','green','green','green','green','green','green','green','green',
          'yellow','yellow','yellow','yellow','yellow','yellow','yellow',
          'orange','orange','orange','orange','orange','orange','orange','orange','orange','orange','orange','orange',
          'orange','orange',
           'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red']

my_cmap = LinearSegmentedColormap.from_list('my_colormap', colors)

plt.figure(figsize=(10, 10))
plt.imshow(emissions_data, cmap=my_cmap)  # Use the custom colormap
plt.title('GHG Emissions Visualization')
plt.axis('off')  # Hide the axis
plt.colorbar(label='GHG Emissions: CO2')  # Optional: Add a colorbar for reference
plt.show()

# %%
# COLORIZING THE MAP: NIKHIL KONDURU

import rasterio
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

tiff = '/content/MiCASA_v1_ATMC_x3600_y1800_daily_20010205.tif'

# Open the GeoTIFF file
with rasterio.open(tiff) as src:
    # Read the band (assuming a single band)
    emissions_data = src.read(1)

# Define a custom colormap
# Example: A colormap with shades of blue, green, and yellow for different values
colors = ['lightgreen','green','green','green','green','green','green','green','green','green','green','darkgreen',
          'yellow','yellow','yellow','yellow','yellow','yellow','yellow',
          'orange','orange','orange','orange','orange','orange','orange','orange','orange','orange','orange','orange',
          'orange','orange',
           'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red']

my_cmap = LinearSegmentedColormap.from_list('my_colormap', colors)

# Display the emissions data with a custom colormap
plt.figure(figsize=(10, 10))
plt.imshow(emissions_data, cmap=my_cmap)  # Use the custom colormap
plt.title('GHG Emissions Visualization')
plt.axis('off')  # Hide the axis
plt.colorbar(label='GHG Emissions: CO2')  # Optional: Add a colorbar for reference
fplt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-d4811e297a23> in <cell line: 3>()
#       1 # COLORIZING THE MAP: NIKHIL KONDURU
#       2
# ----> 3 import rasterio
#       4 import matplotlib.pyplot as plt
#       5 from matplotlib.colors import LinearSegmentedColormap
#
# ModuleNotFoundError: No module named 'rasterio'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.2/22.2 MB 69.1 MB/s eta 0:00:00
# ...

# %%
import rasterio
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

tiff = '/content/MiCASA_v1_ATMC_x3600_y1800_daily_20010315.tif'

with rasterio.open(tiff) as src:
    emissions_data = src.read(1)
colors = ['lightgreen','green','green','green','green','green','green','green','green','green','green','darkgreen',
          'yellow','yellow','yellow','yellow','yellow','yellow','yellow',
          'orange','orange','orange','orange','orange','orange','orange','orange','orange','orange','orange','orange',
          'orange','orange',
           'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red']

my_cmap = LinearSegmentedColormap.from_list('my_colormap', colors)

plt.figure(figsize=(10, 10))
plt.imshow(emissions_data, cmap=my_cmap)
plt.title('GHG Emissions Visualization')
plt.axis('off')
plt.colorbar(label='GHG Emissions: CO2')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-d45e498dd144> in <cell line: 1>()
# ----> 1 import rasterio
#       2 import matplotlib.pyplot as plt
#       3 from matplotlib.colors import LinearSegmentedColormap
#       4
#       5 tiff = '/content/MiCASA_v1_ATMC_x3600_y1800_daily_20010315.tif'
#
# ModuleNotFoundError: No module named 'rasterio'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# COLORIZING THE MAP: NIKHIL KONDURU

import rasterio
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

tiff = '/content/MiCASA_v1_ATMC_x3600_y1800_daily_20010410 (1).tif'

# Open the GeoTIFF file
with rasterio.open(tiff) as src:
    # Read the band (assuming a single band)
    emissions_data = src.read(1)

# Define a custom colormap
# Example: A colormap with shades of blue, green, and yellow for different values
colors = ['lightgreen','green','green','green','green','green','green','green','green','green','green','darkgreen',
          'yellow','yellow','yellow','yellow','yellow','yellow','yellow',
          'orange','orange','orange','orange','orange','orange','orange','orange','orange','orange','orange','orange',
          'orange','orange',
           'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red']

my_cmap = LinearSegmentedColormap.from_list('my_colormap', colors)

# Display the emissions data with a custom colormap
plt.figure(figsize=(10, 10))
plt.imshow(emissions_data, cmap=my_cmap)  # Use the custom colormap
plt.title('GHG Emissions Visualization')
plt.axis('off')  # Hide the axis
plt.colorbar(label='GHG Emissions: CO2')  # Optional: Add a colorbar for reference
plt.show()
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# rasterio/_base.pyx in rasterio._base.DatasetBase.__init__()
#
# rasterio/_base.pyx in rasterio._base.open_dataset()
#
# rasterio/_err.pyx in rasterio._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: /content/MiCASA_v1_ATMC_x3600_y1800_daily_20010410 (1).tif: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# RasterioIOError                           Traceback (most recent call last)
# <ipython-input-5-94865ff86074> in <cell line: 10>()
#       8
#       9 # Open the GeoTIFF file
# ---> 10 with rasterio.open(tiff) as src:
#      11     # Read the band (assuming a single band)
#      12     emissions_data = src.read(1)
#
# /usr/local/lib/python3.10/dist-packages/rasterio/env.py in wrapper(*args, **kwds)
#     461
#     462         with env_ctor(session=session):
# ...

# %% [markdown]
# # **Methane**

# %%
import rasterio
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

tiff = '/content/methane_emis_total_200704.tif'

# Open the GeoTIFF file
with rasterio.open(tiff) as src:
    # Read the band (assuming a single band)
    emissions_data = src.read(1)

#this is
my_cmap = LinearSegmentedColormap.from_list('dramatic_white_red',
                                                    ['black', 'white', 'white', 'white', 'white', 'white', 'white', 'white', 'white', 'white', 'white', 'white','white','white','white','white','white','white','white','white','white','white','white','white','white',])

# Display the emissions data with a custom colormap
plt.figure(figsize=(10, 10))
plt.imshow(emissions_data, cmap=my_cmap)  # Use a perceptually uniform colormap
plt.title('GHG Emissions Visualization')
plt.axis('off')  # Hide the axis
plt.colorbar(label='GHG Emissions: Methane')  # Optional: Add a colorbar for reference
plt.show()

# %%
import rasterio
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

tiff = '/content/methane_emis_fossil_199901.tif'

# Open the GeoTIFF file
with rasterio.open(tiff) as src:
    # Read the band (assuming a single band)
    emissions_data = src.read(1)

#this is
my_cmap = LinearSegmentedColormap.from_list('dramatic_white_red',
                                                    ['black','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white'])

# Display the emissions data with a custom colormap
plt.figure(figsize=(10, 10))
plt.imshow(emissions_data, cmap=my_cmap)  # Use a perceptually uniform colormap
plt.title('GHG Emissions Visualization')
plt.axis('off')  # Hide the axis
plt.colorbar(label='GHG Emissions: Methane')  # Optional: Add a colorbar for reference
plt.show()

# %%
import rasterio
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

tiff = '/content/methane_emis_fossil_199907.tif'

# Open the GeoTIFF file
with rasterio.open(tiff) as src:
    # Read the band (assuming a single band)
    emissions_data = src.read(1)

#this is
my_cmap = LinearSegmentedColormap.from_list('dramatic_white_red',
                                                    ['black','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white'])

# Display the emissions data with a custom colormap
plt.figure(figsize=(10, 10))
plt.imshow(emissions_data, cmap=my_cmap)  # Use a perceptually uniform colormap
plt.title('GHG Emissions Visualization')
plt.axis('off')  # Hide the axis
plt.colorbar(label='GHG Emissions: Methane')  # Optional: Add a colorbar for reference
plt.show()

# %%
import rasterio
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

tiff = '/content/methane_emis_fossil_200010.tif'

# Open the GeoTIFF file
with rasterio.open(tiff) as src:
    # Read the band (assuming a single band)
    emissions_data = src.read(1)

#this is
my_cmap = LinearSegmentedColormap.from_list('dramatic_white_red',
                                                    ['black','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white','white'])

# Display the emissions data with a custom colormap
plt.figure(figsize=(10, 10))
plt.imshow(emissions_data, cmap=my_cmap)  # Use a perceptually uniform colormap
plt.title('GHG Emissions Visualization')
plt.axis('off')  # Hide the axis
plt.colorbar(label='GHG Emissions: Methane')  # Optional: Add a colorbar for reference
plt.show()

# %% [markdown]
# # **Carbon Dioxide (second):**

# %%
# COLORIZING THE MAP: NIKHIL KONDURU

import rasterio
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

tiff = '/content/pilot_topdown_LNLGIS_NBE_std_CO2_Budget_grid_v1_2020.tif'

# Open the GeoTIFF file
with rasterio.open(tiff) as src:
    # Read the band (assuming a single band)
    emissions_data = src.read(1)

# Define a custom colormap
# Example: A colormap with shades of blue, green, and yellow for different values
colors = ['white','darkgreen', 'darkgreen', 'darkgreen','darkgreen','darkgreen','darkgreen','green','green','green','green','green','green','green','green','green','green','green'
          'yellow',
          'orange','orange','orange','orange','orange','orange','orange','orange','orange','orange','orange','orange',
          'orange','orange','orange','orange','orange','orange','orange','orange',
           'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red']

my_cmap = LinearSegmentedColormap.from_list('my_colormap', colors)

# Display the emissions data with a custom colormap
plt.figure(figsize=(10, 10))
plt.imshow(emissions_data, cmap=my_cmap)  # Use the custom colormap
plt.title('GHG Emissions Visualization')
plt.axis('off')  # Hide the axis
plt.colorbar(label='GHG Emissions: CO2')  # Optional: Add a colorbar for reference
plt.show()

# %%
# COLORIZING THE MAP: NIKHIL KONDURU

import rasterio
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

tiff = '/content/pilot_topdown_LNLGIS_NBE_std_CO2_Budget_grid_v1_2019.tif'

# Open the GeoTIFF file
with rasterio.open(tiff) as src:
    # Read the band (assuming a single band)
    emissions_data = src.read(1)

# Define a custom colormap
# Example: A colormap with shades of blue, green, and yellow for different values
colors = ['white','white','white','green','green','green','green','green','green','green','green','green','green','green','green','green','green'
          'yellow',
          'orange','orange','orange','orange','orange','orange','orange','orange','orange','orange','orange','orange',
          'orange','orange','orange','orange','orange','orange','orange','orange',
           'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red']

my_cmap = LinearSegmentedColormap.from_list('my_colormap', colors)

# Display the emissions data with a custom colormap
plt.figure(figsize=(10, 10))
plt.imshow(emissions_data, cmap=my_cmap)  # Use the custom colormap
plt.title('GHG Emissions Visualization')
plt.axis('off')  # Hide the axis
plt.colorbar(label='GHG Emissions: CO2')  # Optional: Add a colorbar for reference
plt.show()

# %%
# COLORIZING THE MAP: NIKHIL KONDURU

import rasterio
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

tiff = '/content/pilot_topdown_LNLGIS_NBE_std_CO2_Budget_grid_v1_2018.tif'

# Open the GeoTIFF file
with rasterio.open(tiff) as src:
    # Read the band (assuming a single band)
    emissions_data = src.read(1)

# Define a custom colormap
# Example: A colormap with shades of blue, green, and yellow for different values
colors = ['white','white','white','green','green','green','green','green','green','green','green','green','green','green','green','green','green'
          'yellow',
          'orange','orange','orange','orange','orange','orange','orange','orange','orange','orange','orange','orange',
          'orange','orange','orange','orange','orange','orange','orange','orange',
           'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red']

my_cmap = LinearSegmentedColormap.from_list('my_colormap', colors)

# Display the emissions data with a custom colormap
plt.figure(figsize=(10, 10))
plt.imshow(emissions_data, cmap=my_cmap)  # Use the custom colormap
plt.title('GHG Emissions Visualization')
plt.axis('off')  # Hide the axis
plt.colorbar(label='GHG Emissions: CO2')  # Optional: Add a colorbar for reference
plt.show()

# %%
# COLORIZING THE MAP: NIKHIL KONDURU

import rasterio
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

tiff = '/content/pilot_topdown_LNLGIS_NBE_std_CO2_Budget_grid_v1_2017.tif'

# Open the GeoTIFF file
with rasterio.open(tiff) as src:
    # Read the band (assuming a single band)
    emissions_data = src.read(1)

# Define a custom colormap
# Example: A colormap with shades of blue, green, and yellow for different values
colors = ['white','white','white','white','green','green','green','green','green','green','green','green','green','green','green','green','green','green'
          'yellow',
          'orange','orange','orange','orange','orange','orange','orange','orange','orange','orange','orange','orange',
          'orange','orange','orange','orange','orange','orange','orange','orange',
           'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red']

my_cmap = LinearSegmentedColormap.from_list('my_colormap', colors)

# Display the emissions data with a custom colormap
plt.figure(figsize=(10, 10))
plt.imshow(emissions_data, cmap=my_cmap)  # Use the custom colormap
plt.title('GHG Emissions Visualization')
plt.axis('off')  # Hide the axis
plt.colorbar(label='GHG Emissions: CO2')  # Optional: Add a colorbar for reference
plt.show()

# %% [markdown]
# # ****

# %%
# COLORIZING THE MAP: NIKHIL KONDURU

import rasterio
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

tiff = '/content/oco2_GEOS_XCO2_L3CO2_day_B10206Ar_20150101.tif'

# Open the GeoTIFF file
with rasterio.open(tiff) as src:
    # Read the band (assuming a single band)
    emissions_data = src.read(1)

# Define a custom colormap
# Example: A colormap with shades of blue, green, and yellow for different values
colors = ['blue','white','red']

my_cmap = LinearSegmentedColormap.from_list('my_colormap', colors)

# Display the emissions data with a custom colormap
plt.figure(figsize=(10, 10))
plt.imshow(emissions_data, cmap="plasma")  # Use the custom colormap
plt.title('GHG Emissions Visualization')
plt.axis('off')  # Hide the axis
plt.colorbar(label='GHG Emissions: CO2')  # Optional: Add a colorbar for reference
plt.show()
